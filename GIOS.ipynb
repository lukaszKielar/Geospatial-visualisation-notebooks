# %% [markdown]
# ## Import libraries

# %%
import requests
import geopandas as gpd
from shapely.geometry import Point
import folium
from folium.plugins import HeatMap
from fiona.crs import from_epsg

# %% [markdown]
# ## Data addresses

# %%
stations_request = "http://api.gios.gov.pl/pjp-api/rest/station/findAll"
sensors_request = "http://api.gios.gov.pl/pjp-api/rest/station/sensors/{stationId}"
data_request = "http://api.gios.gov.pl/pjp-api/rest/data/getData/{sensorId}"
airindex_request = "http://api.gios.gov.pl/pjp-api/rest/aqindex/getIndex/{stationId}"

# %% [markdown]
# ## Get the data

# %%
stations = requests.get("http://api.gios.gov.pl/pjp-api/rest/station/findAll").json()
print("Number of available stations: ", len(stations))
# Out:
# Number of available stations:  158

# %%
stations_dict = {}
station_ids = []
station_lats = []
station_lons = []
station_geometries = []

for station in stations:
    
    station_ids.append(station["id"])
    station_lats.append(float(station["gegrLat"]))
    station_lons.append(float(station["gegrLon"]))
    station_geometries.append(Point(float(station["gegrLon"]), float(station["gegrLat"])))
    
stations_dict["station_id"] = station_ids
stations_dict["lat"] = station_lats
stations_dict["lon"] = station_lons
stations_dict["station_id"] = station_ids
stations_dict["geometry"] = station_geometries

# %%
stations_df = gpd.GeoDataFrame(stations_dict)
stations_df.crs = from_epsg(4326)
stations_df.head()
# Out:
#                       geometry        lat        lon  station_id
# 0  POINT (17.141125 51.115933)  51.115933  17.141125         114
# 1  POINT (17.012689 51.086225)  51.086225  17.012689         129
# 2  POINT (16.180513 51.204503)  51.204503  16.180513          52
# 3  POINT (16.269677 50.768729)  50.768729  16.269677         109
# 4   POINT (16.65366 50.433493)  50.433493  16.653660          38

# %%
stations_geojson = stations_df.to_json()

# %% [markdown]
# ## Plot stations on map

# %%
stations_map = folium.Map([52, 19], zoom_start=6, tiles='Stamen Terrain')

points = folium.features.GeoJson(stations_geojson)

stations_map.add_child(points)
stations_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import numpy as np
import pandas as pd

# test data
stations_df['test data'] = pd.Series(np.random.randn(len(stations_df)))

# %%
stations_df
# Out:
#                         geometry        lat        lon  station_id  test data
# 0    POINT (17.141125 51.115933)  51.115933  17.141125         114  -0.717680
# 1    POINT (17.012689 51.086225)  51.086225  17.012689         129   1.979437
# 2    POINT (16.180513 51.204503)  51.204503  16.180513          52   0.247562
# 3    POINT (16.269677 50.768729)  50.768729  16.269677         109   0.740233
# 4     POINT (16.65366 50.433493)  50.433493  16.653660          38  -1.456478
# 5    POINT (16.514422 50.579914)  50.579914  16.514422          67   1.639316
# 6    POINT (17.291333 50.942073)  50.942073  17.291333          70  -0.528405
# 7     POINT (15.431719 51.31763)  51.317630  15.431719          74  -1.048471
# 8    POINT (15.739722 50.736389)  50.736389  15.739722          84   0.946029
# 9    POINT (16.819786 50.592325)  50.592325  16.819786         132  -0.111649
# 10   POINT (15.008175 51.150391)  51.150391  15.008175         134   0.821555
# 11   POINT (15.765608 50.913433)  50.913433  15.765608        9153  -0.264084
# 12   POINT (16.889899 50.341864)  50.341864  16.889899       10007  -0.095979
# 151  POINT (18.612808 53.017628)  53.017628  18.612808         208   0.105572
# 152  POINT (19.059314 52.658467)  52.658467  19.059314         225  -0.395872
# 153   POINT (18.762139 53.49355)  53.493550  18.762139         142  -0.103482
# 154  POINT (18.241044 52.793122)  52.793122  18.241044         143  -0.634635
# 155  POINT (18.780908 52.888422)  52.888422  18.780908         164  -0.619341
# 156  POINT (18.684258 53.080647)  53.080647  18.684258         190  -1.116484
# 157  POINT (17.934017 53.662117)  53.662117  17.934017         232   0.061436
#
# [158 rows x 5 columns]

# %%
hm_wide = HeatMap([stations_df["lat"], stations_df["lon"], stations_df["test data"]], 
                   min_opacity=0.2,
                   radius=17, blur=15, 
                   max_zoom=1,)

# %% [markdown]
# ## Check available readings for stations

# %%
for station in stations:
    
    print("Available readings for station_id: ", station["id"])
    
    station_id = station["id"]
    sensors = requests.get("http://api.gios.gov.pl/pjp-api/rest/station/sensors/{}".format(station_id)).json()
    
    for sensor in sensors:
        print(sensor["id"], sensor["param"])
    
    print()
# Out:
# Available readings for station_id:  114
# 642 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 644 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  129
# 737 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 740 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 744 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
#
# Available readings for station_id:  52
# 285 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 14397 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 282 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 291 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 293 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 297 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  109
# 608 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 618 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 605 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 614 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 616 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 621 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  38
# 224 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 221 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 223 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 225 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  67
# 14706 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
#
# Available readings for station_id:  70
# 397 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 402 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  74
# 441 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 444 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 450 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  84
# 493 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  132
# 759 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 757 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 760 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  134
# 771 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 14735 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 776 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 782 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  9153
# 14707 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 14730 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 14729 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  10007
# 16415 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 16412 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 16417 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16414 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 16413 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  10008
# 16422 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 16419 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 16393 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16421 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 16420 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  156
# 952 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 965 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 949 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 959 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 966 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 969 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  158
# 987 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 995 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 991 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 996 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 993 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 998 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  295
# 2060 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 2069 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2064 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2071 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 2066 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2076 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  296
# 2080 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 2087 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2079 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 2083 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16805 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 2085 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2088 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  314
# 2199 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2195 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2197 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2204 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  355
# 2370 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 2377 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2373 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2378 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 2382 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  10058
# 16228 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 16250 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 16249 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 16231 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
#
# Available readings for station_id:  291
# 2035 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2031 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2033 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2039 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  319
# 2219 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2221 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2222 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  322
# 2239 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 2245 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2242 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2244 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2248 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  331
# 16642 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 16630 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 16638 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 17716 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 16633 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  562
# 3802 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 14379 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
#
# Available readings for station_id:  9913
# 16037 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16041 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 16043 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  10434
# 17232 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 17239 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 17235 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 17240 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 17237 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 17241 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  590
# 16160 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16158 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 16149 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  10374
# 16147 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
#
# Available readings for station_id:  568
# 3836 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 3843 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 3834 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 3839 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 3844 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 3841 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3847 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  584
# 3902 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 18030 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 14781 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  600
# 3970 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 3964 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 3968 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 3972 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  671
# 4379 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 14466 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 4376 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 4383 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 4385 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 4391 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  638
# 4196 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 4192 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 4194 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 4200 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  659
# 4274 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 14416 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 4278 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 14448 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 4285 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  665
# 4336 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 14771 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 4333 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 4338 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 14772 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 4339 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  870
# 5716 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 5718 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 5720 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 5722 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  882
# 16424 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 5826 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 16396 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  10005
# 16173 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 16216 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16171 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 16214 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  10030
# 16174 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 16178 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 16181 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16180 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 16177 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  943
# 6062 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 6067 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 6065 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 6071 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  944
# 6076 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 6085 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 6074 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 6081 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 6083 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
{'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 4764 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  738
# 4774 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 4769 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 4772 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 4777 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  739
# 4793 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 4791 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
#
# Available readings for station_id:  725
# 4632 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 16071 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 4629 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 4638 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 4640 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 4649 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  740
# 4806 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 4817 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 16057 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 4812 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 4819 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 4814 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 4822 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  741
# 4834 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 4845 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 4840 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 4842 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 4848 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  742
# 4860 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 16070 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 4866 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# ...
# Available readings for station_id:  9179
# 14804 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 14826 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  10119
# 16486 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16488 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  10124
# 16498 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
#
# Available readings for station_id:  10254
# 16905 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 16904 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  530
# 3576 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 3584 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 3575 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 3580 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 3585 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
#
# Available readings for station_id:  531
# 3591 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  538
# 3654 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 3650 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 18038 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
#
# Available readings for station_id:  550
# 3730 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 3725 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 3731 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 3727 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3736 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  552
# 3764 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 3760 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 14688 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 3762 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3769 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  497
# 3409 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 3407 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 3412 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 3414 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3418 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  501
# 3420 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 3429 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 3419 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 3425 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 14376 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 16765 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3434 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  515
# 3487 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 3497 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 3486 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 3492 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 14377 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 3494 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3502 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  460
# 3199 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 3201 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 3203 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3205 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  466
# 3229 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 3231 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3237 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  471
# 3257 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 14378 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 3259 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3265 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  485
# 16046 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 17225 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 16048 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16044 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 16050 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 16051 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  488
# 3339 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 14779 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 14352 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 3348 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  517
# 3526 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 3528 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
#
# Available readings for station_id:  266
# 1888 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 1900 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 1885 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 1895 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 16472 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 1897 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 1902 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  236
# 18009 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 15727 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 1676 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 14348 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  248
# 1741 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  282
# 1983 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  285
# 16744 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 14367 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 2001 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2008 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  9593
# 15688 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
#
# Available readings for station_id:  10874
# 18039 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 18042 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 18041 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  361
# 2411 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 2421 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2418 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2425 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  387
# 2649 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 14428 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2647 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 2657 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2664 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 2659 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2668 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  374
# 2504 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2506 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2510 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  376
# 2519 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 2528 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2523 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2525 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2532 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  379
# 2554 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 2563 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2559 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 14633 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2566 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  382
# 2589 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 14618 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 2594 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 2596 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 2601 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  145
# 853 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 850 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 855 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  206
# 1405 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 1407 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 1403 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  208
# 1416 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 1426 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 1414 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 1421 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 1429 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  225
# 1534 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 1544 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 18023 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 1539 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 19698 {'paramName': 'pył zawieszony PM2.5', 'paramFormula': 'PM2.5', 'paramCode': 'PM2.5', 'idParam': 69}
# 1548 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  142
# 806 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 812 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 809 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 814 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  143
# 828 {'paramName': 'pył zawieszony PM10', 'paramFormula': 'PM10', 'paramCode': 'PM10', 'idParam': 3}
# 824 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 831 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  164
# 1048 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 1061 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 1063 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
#
# Available readings for station_id:  190
# 1283 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 1285 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 1289 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
#
# Available readings for station_id:  232
# 1607 {'paramName': 'tlenek węgla', 'paramFormula': 'CO', 'paramCode': 'CO', 'idParam': 8}
# 1600 {'paramName': 'benzen', 'paramFormula': 'C6H6', 'paramCode': 'C6H6', 'idParam': 10}
# 1635 {'paramName': 'dwutlenek azotu', 'paramFormula': 'NO2', 'paramCode': 'NO2', 'idParam': 6}
# 1640 {'paramName': 'ozon', 'paramFormula': 'O3', 'paramCode': 'O3', 'idParam': 5}
# 1650 {'paramName': 'dwutlenek siarki', 'paramFormula': 'SO2', 'paramCode': 'SO2', 'idParam': 1}
